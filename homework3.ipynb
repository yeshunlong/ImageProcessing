# %%
import cv2  
import numpy as np  
import matplotlib.pyplot as plt
import math

# %%
img = cv2.imread('dataset/lena.jpg')
grayImage = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
height = grayImage.shape[0]
width = grayImage.shape[1]

# %%
img_fft = np.fft.fft2(grayImage)
img_fftshift = np.fft.fftshift(img_fft)

# %% [markdown]
# #### 幅度谱、相位谱

# %%
img_rebulid = np.fft.ifft2(np.abs(img_fft)*np.exp(1j*(np.angle(img_fft))))
rebulid = np.real(img_rebulid)

plt.figure(figsize=(10, 12))
plt.subplot(121), plt.imshow(grayImage, 'gray'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(rebulid, 'gray'), plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 相位谱为0，幅度谱

# %%
img_magnitude = np.log(np.abs(img_fftshift))
magnitude = np.real(np.fft.ifft2(np.abs(img_fft)))

plt.figure(figsize=(10, 12))
plt.subplot(121), plt.imshow(grayImage, 'gray'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(magnitude, 'gray'), plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 幅度谱为1，相位谱

# %%
img_phase = np.log(np.angle(img_fftshift)*180/math.pi)
phase = np.real(np.fft.ifft2(np.exp(1j*np.angle(img_fft))))

plt.figure(figsize=(10, 12))
plt.subplot(121), plt.imshow(grayImage, 'gray'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(phase, 'gray'), plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17756\2794907552.py:1: RuntimeWarning: divide by zero encountered in log
#   img_phase = np.log(np.angle(img_fftshift)*180/math.pi)
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17756\2794907552.py:1: RuntimeWarning: invalid value encountered in log
#   img_phase = np.log(np.angle(img_fftshift)*180/math.pi)
